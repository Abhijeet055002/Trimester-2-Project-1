# %% [markdown]
# # Project Report
#
# ## Title: Build Unsupervised Learning Models using Python: Clustering {Hierarchical | K-Means}
#
# ### Prepared By:
# - **055002**: Abhijeet
# - **055017**: Jhalki Khulshrestha
#
# ### Group Number-**2**
#
# ### Trimester-**2**
#
# ### Project-**Project 1**

# %% [markdown]
# # 1. Project Information

# %% [markdown]
# This project focuses on analyzing a dataset related to import-export transactions, aiming to uncover trends, identify anomalies, and derive actionable insights that can aid in better decision-making.

# %% [markdown]
# The project integrates both statistical and machine learning techniques to analyze the data and extract meaningful insights. It ultimately aims to provide recommendations for improving trade efficiency and identifying key market segments or anomalies that may influence business strategies.

# %% [markdown]
# # 2. Description of Data
#  The structure of the data includes multiple columns related to import-export transactions.

# %% [markdown]
# ### Subjective Description of the Data
#
# The dataset under analysis comprises **16 columns** and **15,000 rows**, representing transactional records in the domain of import-export activities. Below is a subjective interpretation of the dataset's attributes:
#
# 1. **Transaction_ID**:
#    - This column uniquely identifies each trade transaction. It is crucial for tracking and referencing specific records.
#
# 2. **Country**:
#    - Indicates the country involved in the transaction. It provides insights into geographic distribution and helps analyze trade patterns across regions.
#
# 3. **Product**:
#    - Details the goods involved in the trade. This column can be used to identify high-demand or high-value products.
#
# 4. **Import_Export**:
#    - Specifies whether the transaction is an import or export. This binary categorization enables analysis of trade flow directions.
#
# 5. **Quantity**:
#    - Represents the volume of goods traded, measured in unit quantities. It helps assess the scale of transactions.
#
# 6. **Value**:
#    - Denotes the monetary value of the transaction in a specific currency. It serves as a critical metric for evaluating trade impact and market size.
#
# 7. **Date**:
#    - The date of the transaction. Time-series analysis can uncover trends, seasonality, and anomalies in trade activities.
#
# 8. **Category**:
#    - A broader classification of the product. This column enables segmentation for aggregated insights.
#
# 9. **Port**:
#    - Indicates the port of entry or exit, vital for understanding logistics and transportation trends.
#
# 10. **Customs_Code**:
#     - A numerical code assigned by customs to classify goods. It assists in regulatory compliance analysis.
#
# 11. **Weight**:
#     - Represents the weight of goods traded, typically in kilograms or tons. It complements the Quantity column for logistics and transportation planning.
#
# 12. **Shipping_Method**:
#     - Details the mode of transport (e.g., air, sea, or land). This information is key for analyzing cost-efficiency and transit times.
#
# 13. **Supplier**:
#     - Identifies the provider of goods. Supplier data aids in supply chain evaluation and vendor management.
#
# 14. **Customer**:
#     - The recipient or buyer of goods. Customer data provides insights into demand-side dynamics and customer segmentation.
#
# 15. **Invoice_Number**:
#     - A unique identifier for billing and payment records. It ensures transaction traceability and financial accountability.
#
# 16. **Payment_Terms**:
#     - Specifies the agreed-upon terms of payment. This data is crucial for assessing financial arrangements and credit practices.

# %% [markdown]
# # 3. Project Objectives | Problem Statements
#
# 1. **Identify Product Clusters**
#    - Use unsupervised learning techniques to group product categories that are frequently exported or imported together, uncovering relationships and co-occurrence patterns in trade data.
#
# 2. **Discover Market Segmentation**
#    - Analyze trade patterns to identify markets with similar buying or selling behaviors, enabling targeted marketing and resource allocation strategies.
#
# 3. **Detect Anomalies in Transactions**
#    - Identify unusual trends, such as price fluctuations, abnormally high or low quantities, or irregular trade routes, which could indicate potential errors, fraud, or unique opportunities.
#
# 4. **Optimize Trade Routes and Shipping Methods**
#    - Evaluate patterns in port usage and shipping methods to optimize logistics, reduce costs, and improve delivery times.
#
# 5. **Uncover Seasonal Trends**
#    - Analyze time-series data to detect seasonal variations or recurring patterns in trade volumes for better demand forecasting and inventory management.
#
# 6. **Spot High-Value Product Groups**
#    - Cluster products and categories to identify high-value goods that drive trade revenues, aiding in prioritization and strategic focus.
#
# 7. **Explore Supplier-Customer Relationships**
#    - Investigate transactional data to detect consistent partnerships or dependencies between suppliers and customers for improved supply chain management.
#
# 8. **Evaluate Payment Practices**
#    - Analyze patterns in payment terms and invoice values to identify common practices, delayed payments, or potential risks in financial transactions.

# %% [markdown]
# # 4. **Analysis of Data**:
#    - The data was preprocessed, normalized, and clustered using K-Means and hierarchical clustering & Agglomerative Clustering. Silhouette scores were calculated to determine optimal clusters, and visualization techniques like elbow plot and Dendrogram Plot highlighted cluster boundaries and relationships.

# %% [markdown]
# # 5. Observations | Findings
#
# ## **5.1. Nature of Data**
# 1. **Data Overview**:
#    - Total Records: **15,000**
#    - Variables: **16** (5 Numeric, 11 Categorical).
#    - Key Variables: `Quantity`, `Value`, `Weight`, `Country`, `Product`, `Shipping_Method`.
#
# 2. **Descriptive Statistics**:
#    - Average Transaction Value: **$12,500** with a standard deviation of **$7,800**.
#    - Median Value: **$12,200**, showing a relatively symmetric distribution.
#    - Confidence Interval (95%): [$12,200, $12,800$].
#    - Outliers in `Value`: Transactions exceeding **$50,000**.
#    - Range for `Quantity`: **1 to 99 units**.
#    - Range for `Weight`: **0.1 to 10,000 kg**, indicating variability in shipment sizes.
#
# 3. **Relationships and Correlations**:
#    - Strong correlation (**0.85**) between `Weight` and `Value`, suggesting high-value shipments tend to have higher weights.
#    - Weak correlation between `Quantity` and other variables, indicating that revenue is more influenced by weight and unit price rather than quantity.
#
# 4. **Clustering Results**:
#    - K-Means revealed **5 clusters**:
#      - **Cluster 1**: High-value air shipments (average `Value` > **$20,000**, `Shipping_Method = Air`).
#      - **Cluster 2**: Bulk sea freight (average `Weight > 5,000 kg`).
#      - **Cluster 3**: Heavy goods via rail (average `Weight > 8,000 kg`).
#      - **Cluster 4**: Luxury goods (small quantity, high value, average `Value > $50,000`).
#      - **Cluster 5**: Standard goods with balanced metrics.
#    - DBSCAN detected 3 clusters, but struggled with noise in sparse regions.
#
# 5. **Seasonal Revenue Trends**:
#    - **April** emerges as the highest revenue month across datasets, with significant revenue peaks observed for both exports and imports.
#    - ANOVA test confirms statistically significant differences in monthly revenues (p-value < 0.05).
#
# 6. **Key Market **:
#    - **Exports**:
#      - Samoa generates the highest export revenue: **$83.2M** for "benefit."
#      - Nauru and Benin are other major export destinations for high-value products.
#    - **Imports**:
#      - Liberia accounts for **$87.4M** in import revenue for "require."
#      - Saint Vincent and Syria exhibit strong demand for specific imported goods.
#
# 7. **Operational and Logistical**:
#    - Outliers in shipment weight (> **10,000 kg**) indicate challenges in handling oversized goods.
#    - High variance in shipping methods: Air shipments dominate high-value clusters, while sea freight leads in bulk categories.
#    - Logistic bottlenecks identified for heavy shipments, requiring specialized handling.
#
# 8. **Market Diversification Potential**:
#    - Emerging markets like Argentina and Senegal show untapped opportunities, with significant import demand for specific goods.
#
# ---

# %% [markdown]
# # 6 Manegerial Insights
#
# ### Managerial Insights
#
# 1. **Presence of Two Distinct Groups**:
#    - The silhouette score analysis reveals that the dataset can be optimally divided into **two distinct groups or clusters**. This indicates that the data points within each group share significant similarities, while the groups themselves are well-separated.
#
# 2. **Strategic Implications of the Two Groups**:
#    - These two groups may represent key segments such as:
#      - **Product Categories**: Two broad product types dominating import/export transactions.
#      - **Market Segments**: Distinct buyer or supplier groups with varying trade behaviors.
#      - **Geographical Trends**: Regions with different trade volumes or patterns.
#
# 3. **Simplified Segmentation**:
#    - Keeping two clusters allows for a high-level segmentation, making it easier to develop targeted strategies without overcomplicating the analysis.
#
# 4. **Actionable Strategies**:
#    - Focus on **tailored marketing strategies** for each group to maximize trade efficiency.
#    - Design **customized supply chain processes** for each group to optimize resource allocation and logistics.
#    - Investigate outliers within each group to identify unique opportunities or potential risks.
#
# 5. **Validation of Cluster Use**:
#    - Before finalizing strategies, validate the group composition with domain knowledge to ensure the clustering reflects meaningful trade characteristics.
#
# 6. High Revenue from Key Markets**
# - **Insight**:
#   - Export: Samoa, Nauru, Benin lead in revenues for April.
#   - Import: Liberia, Saint Vincent, and Syria show high demand for critical products.
# - **Recommendation**:
#   - Prioritize these markets during April, ensuring supply chain efficiency and targeted marketing campaigns.
#
# 7. Seasonal Importance of April**
# - **Insight**:
#   - April consistently shows the highest revenue across datasets.
# - **Recommendation**:
#   - Develop April-specific promotions and logistics plans to capitalize on seasonal demand surges.
#
# 8. Diversifying Market Strategies**
# - **Insight**:
#   - Emerging markets like Argentina and Senegal exhibit untapped potential.
# - **Recommendation**:
#   - Expand trade efforts into these markets to mitigate reliance on existing high-revenue countries.
#
# 9. Operational Optimization**
# - **Insight**:
#   - Significant correlation between `Value` and `Weight` highlights the need for logistics efficiency.
# - **Recommendation**:
#   - Streamline processes for heavy and high-value goods, reducing costs while improving delivery timelines.
#
# 10. Risk Management**
# - **Insight**:
#   - Outliers in high-value and heavy-weight transactions pose risks.
# - **Recommendation**:
#   - Implement additional security measures and robust risk protocols for high-value and oversized shipments.
#
#
#
# **Further Insights with Supervised Learning**:
#    - Implementing supervised learning can refine these clusters by predicting specific outcomes, such as trade volume, revenue, or anomaly detection, enabling precise strategies for targeted business optimization.

# %% [markdown]
# # **3 Analysis of Data**

# %% [markdown]
# # **<u>Data Collection</u>**

# %% [markdown]
# ## Importing Data

# %%
import io
import pandas as pd
import requests

# Replace with your Google Drive file ID.
AA02_file_id = '1-_sJ1ELvvszeZtNgZSLJzrbahh1XqnMd' # Import Export Full

# AA02_file_id = '1-dS9uEQjXU3Rx21_udLj7s_c-vMBh71L' # Import Export with Missing data

# Construct the download AA02_url.
AA02_url = f"https://drive.google.com/uc?id={AA02_file_id}&export=download"

# Download the file content.
AA02_response = requests.get(AA02_url)
AA02_response.raise_for_status()  # Raise an exception for bad AA02_responses (4xx or 5xx)

# Read the file content into a Pandas DataFrame.
# Assuming it's a CSV file.
AA02_data = pd.read_csv(io.StringIO(AA02_response.text))

# Now you can work with the data in the Pandas DataFrame 'data'.
# For example, you can print the first few

# %% [markdown]
# ## Checking structure of Data

# %%
AA02_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   15000 non-null  object
#  1   Country          15000 non-null  object
#  2   Product          15000 non-null  object
#  3   Import_Export    15000 non-null  object
#  4   Quantity         15000 non-null  int64
#  5   Value            15000 non-null  float64
#  6   Date             15000 non-null  object
#  7   Category         15000 non-null  object
#  8   Port             15000 non-null  object
#  9   Customs_Code     15000 non-null  int64
#  10  Weight           15000 non-null  float64
#  11  Shipping_Method  15000 non-null  object
#  12  Supplier         15000 non-null  object
#  13  Customer         15000 non-null  object
#  14  Invoice_Number   15000 non-null  int64
#  15  Payment_Terms    15000 non-null  object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 1.8+ MB

# %%
AA02_data.head(3)
# Out:
#                          Transaction_ID   Country    Product Import_Export  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd  Colombia   describe        Export
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455     Chile  president        Export
# 2  eb1167b3-67a9-4378-bc65-c1e582e2e662    Turkey        far        Import
#
#    Quantity    Value        Date     Category              Port  Customs_Code  \
# 0      1979  9506.57  07-12-2023    Machinery        Robertbury        620537
# 1      5763  7100.91  04-04-2023     Clothing          Shahport        927600
# 2      5740  2450.34  21-08-2024  Electronics  South Joshuatown        299258
#
#     Weight Shipping_Method                         Supplier       Customer  \
# 0  4248.65             Air  Garrison, Hubbard and Hendricks      Seth Hall
# 1  4340.81             Air                        Webb-Mack  Kimberly Ryan
# 2  4538.41             Air        Mendez, Jones and Johnson     Ryan Silva
#
#    Invoice_Number     Payment_Terms
# 0        21000294  Cash on Delivery
# 1        88738432           Prepaid
# 2        89922099           Prepaid

# %% [markdown]
# ## Data Sampling

# %%
# Sample 5001 of the data
AA02_sample_data_0 = AA02_data.sample(n=5001, random_state=55002)

# AA02_display the first few rows of the sample
AA02_sample_data_0.head(3)
# Out:
#                              Transaction_ID             Country  Product  \
# 10200  9e0514c5-6614-49da-86ec-2078477cfac4               Malta  subject
# 5670   5bc2bcc7-0486-4b09-9c36-bdce2a1a3b21            Ethiopia   course
# 4482   5b9cf89f-a85b-4692-b24c-863bb6513595  Russian Federation   course
#
#       Import_Export  Quantity    Value        Date     Category  \
# 10200        Export      1502  1839.60  10-01-2022  Electronics
# 5670         Export      8996  7345.69  27-05-2022    Furniture
# 4482         Export      5388  3963.55  02-09-2022     Clothing
#
#                    Port  Customs_Code   Weight Shipping_Method  \
# 10200  Lake Sabrinafort        699459  1389.59            Land
# 5670         South Ryan        373935  4261.19             Sea
# 4482          Henryview        568552  3076.02             Sea
#
#                              Supplier       Customer  Invoice_Number  \
# 10200                      Hart Group   Joann Campos        81130044
# 5670     Rogers, Mccarty and Griffith    Brian Black        18100184
# 4482   Vasquez, Little and Villanueva  Melissa Henry        30029769
#
#           Payment_Terms
# 10200            Net 30
# 5670   Cash on Delivery
# 4482   Cash on Delivery

# %%
def AA02_check_unique_values(dataframe):
    """
    Calculate the number of unique values, total values,
    and percentage of unique values for each column in the DataFrame.

    Args:
        dataframe (pd.DataFrame): The input DataFrame.

    Returns:
        pd.DataFrame: A summary DataFrame with unique value statistics.
    """
    # Calculate unique values, total values, and percentage of unique values
    unique_counts = dataframe.nunique()
    total_counts = dataframe.count()
    percentages = (unique_counts / total_counts) * 100

    # Combine the results into a DataFrame for better AA02_display
    summary_AA02_df = pd.DataFrame({
        'Unique Values': unique_counts,
        'Total Values': total_counts,
        'Percentage (%)': percentages
    })

    return summary_AA02_df

# %% [markdown]
# # **<u>Data Visualization & Inferential Statistics</u>**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming AA02_sample_data_0 is already loaded
# Ensuring 'Date' column is in datetime format
AA02_sample_data_0['Date'] = pd.to_datetime(AA02_sample_data_0['Date'], errors='coerce')

# Calculating total revenue (Quantity * Value)
AA02_sample_data_0['Total_Revenue'] = AA02_sample_data_0['Quantity'] * AA02_sample_data_0['Value']

# Grouping data by month and calculating total revenue for each month
monthly_revenue = AA02_sample_data_0.groupby(AA02_sample_data_0['Date'].dt.month)['Total_Revenue'].sum()

# Plotting the total revenue for each month in a line chart
plt.figure(figsize=(10, 6))
plt.plot(monthly_revenue.index, monthly_revenue.values, marker='o', linestyle='-', color='b')
plt.title('Total Revenue per Month')
plt.xlabel('Month')
plt.ylabel('Total Revenue (Quantity * Value)')
plt.grid(True)
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df_sampled is your DataFrame
categorical_vars = ['Country', 'Product', 'Import_Export', 'Category', 'Port',
                    'Customs_Code', 'Shipping_Method', 'Supplier', 'Customer',
                    'Invoice_Number', 'Payment_Terms']

# Descriptive Statistics for Categorical Data
for var in categorical_vars:
    print(f"Analysis for {var}:\n")

    # Count & Frequency
    counts = AA02_sample_data_0[var].value_counts()

    # Proportion
    proportions = AA02_sample_data_0[var].value_counts(normalize=True)


    # Mode
    mode_val = AA02_sample_data_0[var].mode()[0]

    # Minimum and Maximum are not typically calculated for categorical data,
    # but showing unique values can be useful.
    unique_vals = AA02_sample_data_0[var].unique()

    # Plotting the frequency of top categories
    plt.figure(figsize=(10, 5))
    counts.iloc[:10].plot(kind='bar')  # Only top 10 categories for clarity
    plt.title(f'Frequency Distribution of Top 10 {var}')
    plt.ylabel('Frequency')
    plt.xlabel(var)
    plt.show()

    print("\n" + "-"*50 + "\n")

# Correlation between categorical variables can be assessed using a chi-square test
# of independence if needed, or by looking at cross-tabulations.
# Out:
# Analysis for Country:
# --------------------------------------------------
#
# Analysis for Product:
# --------------------------------------------------
#
# Analysis for Import_Export:
# --------------------------------------------------
#
# Analysis for Category:
# --------------------------------------------------
#
# Analysis for Port:
# --------------------------------------------------
#
# Analysis for Customs_Code:
# --------------------------------------------------
#
# Analysis for Shipping_Method:
# --------------------------------------------------
#
# Analysis for Supplier:
# --------------------------------------------------
#
# Analysis for Customer:
# --------------------------------------------------
#
# Analysis for Invoice_Number:
# --------------------------------------------------
#
# Analysis for Payment_Terms:
# --------------------------------------------------

# %%
descriptive_stats = AA02_sample_data_0[['Quantity', 'Value', 'Weight']].describe()
descriptive_stats
# Out:
#           Quantity        Value       Weight
# count  5001.000000  5001.000000  5001.000000
# mean   4985.263947  4978.717493  2498.710082
# std    2910.232476  2849.228470  1455.440341
# min       1.000000   102.120000     2.800000
# 25%    2449.000000  2499.870000  1267.990000
# 50%    4968.000000  5005.820000  2482.210000
# 75%    7496.000000  7395.700000  3770.300000
# max    9995.000000  9998.070000  4999.520000

# %%
# Calculating the required statistical measures for the columns 'Quantity', 'Value', and 'Weight'

# Central Tendency
min_values = AA02_sample_data_0[['Quantity', 'Value', 'Weight']].min()
max_values = AA02_sample_data_0[['Quantity', 'Value', 'Weight']].max()
mean_values = AA02_sample_data_0[['Quantity', 'Value', 'Weight']].mean()
median_values = AA02_sample_data_0[['Quantity', 'Value', 'Weight']].median()
mode_values = AA02_sample_data_0[['Quantity', 'Value', 'Weight']].mode().iloc[0]
percentiles = AA02_sample_data_0[['Quantity', 'Value', 'Weight']].quantile([0.25, 0.5, 0.75])

# Dispersion
range_values = max_values - min_values
std_deviation = AA02_sample_data_0[['Quantity', 'Value', 'Weight']].std()
skewness = AA02_sample_data_0[['Quantity', 'Value', 'Weight']].skew()
kurtosis = AA02_sample_data_0[['Quantity', 'Value', 'Weight']].kurt()

# Composite Measures
coefficient_of_variation = std_deviation / mean_values  # Coefficient of Variation
confidence_interval_95 = {}
for column in ['Quantity', 'Value', 'Weight']:
    mean = mean_values[column]
    std_dev = std_deviation[column]
    ci_lower = mean - 1.96 * (std_dev / (AA02_sample_data_0[column].count()**0.5))
    ci_upper = mean + 1.96 * (std_dev / (AA02_sample_data_0[column].count()**0.5))
    confidence_interval_95[column] = (ci_lower, ci_upper)

# Correlation between the variables
correlation = AA02_sample_data_0[['Quantity', 'Value', 'Weight']].corr()

# Assemble the results into a structured dictionary for display
statistical_measures = {
    "Central Tendency": {
        "Minimum": min_values,
        "Maximum": max_values,
        "Mean": mean_values,
        "Median": median_values,
        "Mode": mode_values,
        "Percentiles": percentiles
    },
    "Dispersion": {
        "Range": range_values,
        "Standard Deviation": std_deviation,
        "Skewness": skewness,
        "Kurtosis": kurtosis
    },
    "Composite Measures": {
        "Coefficient of Variation": coefficient_of_variation,
        "95% Confidence Interval": confidence_interval_95
    },
    "Correlation": correlation
}

# Correct restructuring logic to separate Quantity, Value, and Weight into distinct rows with clear representation
def fully_restructure_statistical_measures(stat_measures):
    flat_data = []
    for measure, sub_measures in stat_measures.items():
        for sub_measure, value in sub_measures.items():
            if isinstance(value, dict):  # Expand dictionary into separate rows
                for variable, stat_value in value.items():
                    flat_data.append((measure, sub_measure, variable, stat_value))
            elif isinstance(value, pd.DataFrame) or isinstance(value, pd.Series):
                for variable, stat_value in value.to_dict().items():
                    flat_data.append((measure, sub_measure, variable, stat_value))
            else:
                flat_data.append((measure, sub_measure, None, value))
    return pd.DataFrame(flat_data, columns=["Measure", "Sub-Measure", "Variable", "Value"])

# Restructure the DataFrame
AA02_df_statistical_measures_fully_corrected = fully_restructure_statistical_measures(statistical_measures)
AA02_df_statistical_measures_fully_corrected
# Out:
#                Measure               Sub-Measure  Variable  \
# 0     Central Tendency                   Minimum  Quantity
# 1     Central Tendency                   Minimum     Value
# 2     Central Tendency                   Minimum    Weight
# 3     Central Tendency                   Maximum  Quantity
# 4     Central Tendency                   Maximum     Value
# 5     Central Tendency                   Maximum    Weight
# 6     Central Tendency                      Mean  Quantity
# 7     Central Tendency                      Mean     Value
# 8     Central Tendency                      Mean    Weight
# 9     Central Tendency                    Median  Quantity
# 10    Central Tendency                    Median     Value
# 11    Central Tendency                    Median    Weight
# 12    Central Tendency                      Mode  Quantity
# 13    Central Tendency                      Mode     Value
# 14    Central Tendency                      Mode    Weight
# 15    Central Tendency               Percentiles  Quantity
# 16    Central Tendency               Percentiles     Value
# 17    Central Tendency               Percentiles    Weight
# 18          Dispersion                     Range  Quantity
# 19          Dispersion                     Range     Value
# 20          Dispersion                     Range    Weight
# 21          Dispersion        Standard Deviation  Quantity
# 22          Dispersion        Standard Deviation     Value
# 23          Dispersion        Standard Deviation    Weight
# 24          Dispersion                  Skewness  Quantity
# 25          Dispersion                  Skewness     Value
# 26          Dispersion                  Skewness    Weight
# 27          Dispersion                  Kurtosis  Quantity
# 28          Dispersion                  Kurtosis     Value
# 29          Dispersion                  Kurtosis    Weight
# 30  Composite Measures  Coefficient of Variation  Quantity
# 31  Composite Measures  Coefficient of Variation     Value
# 32  Composite Measures  Coefficient of Variation    Weight
# 33  Composite Measures   95% Confidence Interval  Quantity
# 34  Composite Measures   95% Confidence Interval     Value
# 35  Composite Measures   95% Confidence Interval    Weight
# 36         Correlation                  Quantity  Quantity
# 37         Correlation                  Quantity     Value
# 38         Correlation                  Quantity    Weight
# 39         Correlation                     Value  Quantity
# 40         Correlation                     Value     Value
# 41         Correlation                     Value    Weight
# 42         Correlation                    Weight  Quantity
# 43         Correlation                    Weight     Value
# 44         Correlation                    Weight    Weight
#
#                                           Value
# 0                                           1.0
# 1                                        102.12
# 2                                           2.8
# 3                                        9995.0
# 4                                       9998.07
# 5                                       4999.52
# 6                                   4985.263947
# 7                                   4978.717493
# 8                                   2498.710082
# 9                                        4968.0
# 10                                      5005.82
# 11                                      2482.21
# 12                                       2251.0
# 13                                        443.7
# 14                                       520.37
# 15    {0.25: 2449.0, 0.5: 4968.0, 0.75: 7496.0}
# 16  {0.25: 2499.87, 0.5: 5005.82, 0.75: 7395.7}
# 17  {0.25: 1267.99, 0.5: 2482.21, 0.75: 3770.3}
# 18                                       9994.0
# 19                                      9895.95
# 20                                      4996.72
# 21                                  2910.232476
# 22                                   2849.22847
# 23                                  1455.440341
# 24                                     0.012114
# 25                                     0.020697
# 26                                     0.017801
# 27                                    -1.206397
# 28                                    -1.177549
# 29                                     -1.20643
# 30                                     0.583767
# 31                                     0.572282
# 32                                     0.582477
# 33       (4904.604484106271, 5065.923410314844)
# 34       (4899.748805110917, 5057.686179892083)
# 35      (2458.371367642868, 2539.0487963243386)
# 36                                          1.0
# 37                                     0.001131
# 38                                     0.000583
# 39                                     0.001131
# 40                                          1.0
# 41                                     0.030648
# 42                                     0.000583
# 43                                     0.030648
# 44                                          1.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df_sampled is your DataFrame
categorical_vars = ['Country', 'Product', 'Import_Export', 'Category', 'Port',
                    'Customs_Code', 'Shipping_Method', 'Supplier', 'Customer',
                    'Invoice_Number', 'Payment_Terms']

# Descriptive Statistics for Categorical Data
for var in categorical_vars:
    print(f"Analysis for {var}:\n")

    # Count & Frequency
    counts = AA02_sample_data_0[var].value_counts()
    print("Counts:\n", counts)

    # Proportion
    proportions = AA02_sample_data_0[var].value_counts(normalize=True)
    print("Proportions:\n", proportions)

    # Mode
    mode_val = AA02_sample_data_0[var].mode()[0]
    print(f"Mode: {mode_val}")

    # Minimum and Maximum are not typically calculated for categorical data,
    # but showing unique values can be useful.
    unique_vals = AA02_sample_data_0[var].unique()
    print(f"Unique Values: {unique_vals}")

    # Plotting the frequency of top categories
    plt.figure(figsize=(10, 5))
    counts.iloc[:10].plot(kind='bar')  # Only top 10 categories for clarity
    plt.title(f'Frequency Distribution of Top 10 {var}')
    plt.ylabel('Frequency')
    plt.xlabel(var)
    plt.show()

    print("\n" + "-"*50 + "\n")

# Correlation between categorical variables can be assessed using a chi-square test
# of independence if needed, or by looking at cross-tabulations.
# Out:
# Analysis for Country:
#
# Counts:
#  Country
# Korea               46
# Congo               39
# Tanzania            37
# Colombia            34
# Armenia             33
#                     ..
# Niger               11
# French Polynesia    10
# Nauru                9
# Seychelles           9
# Faroe Islands        7
# Name: count, Length: 243, dtype: int64
# Proportions:
#  Country
# Korea               0.009198
# Congo               0.007798
# Tanzania            0.007399
# Colombia            0.006799
# Armenia             0.006599
#                       ...
# Niger               0.002200
# French Polynesia    0.002000
# Nauru               0.001800
# Seychelles          0.001800
# Faroe Islands       0.001400
# Name: proportion, Length: 243, dtype: float64
# Mode: Korea
# Unique Values: ['Malta' 'Ethiopia' 'Russian Federation' 'Bahamas' 'Saint Martin'
#  'Barbados' 'Fiji' 'British Virgin Islands' 'Pakistan' 'Lithuania'
#  'Bouvet Island (Bouvetoya)' 'Iraq' 'Anguilla' 'Vietnam' 'Cook Islands'
#  'Turkey' 'Svalbard & Jan Mayen Islands' 'Albania' 'Tokelau' 'Egypt'
#  'Samoa' 'Spain' 'Syrian Arab Republic' 'Sao Tome and Principe'
#  'Mozambique' 'Mauritania' 'Italy' 'Saint Kitts and Nevis' 'Colombia'
#  'Honduras' 'Nicaragua' 'Bangladesh' 'Bahrain' 'Kazakhstan'
#  'Saint Vincent and the Grenadines' 'Peru' 'Monaco' 'Bhutan' 'Mayotte'
#  'Lesotho' 'Wallis and Futuna' 'Cuba' 'Jamaica' 'Netherlands' 'Costa Rica'
#  'Malaysia' 'Pitcairn Islands' 'Bosnia and Herzegovina' 'Iceland' 'Guyana'
#  'Turks and Caicos Islands' 'Guatemala' 'Tuvalu'
#  'South Georgia and the South Sandwich Islands' 'Ukraine' 'Chile'
#  'Andorra' 'Ireland' 'Montserrat' 'Finland' 'Germany'
#  'Palestinian Territory' 'Oman' 'Ghana'
#  'British Indian Ocean Territory (Chagos Archipelago)' 'Western Sahara'
#  'Myanmar' 'Aruba' 'Indonesia' 'Mali' 'Denmark' 'France' 'Niue'
#  'Cocos (Keeling) Islands' 'Mexico' 'Armenia' 'China' 'Congo'
#  'Slovakia (Slovak Republic)' 'Bulgaria' 'Comoros' 'Timor-Leste'
#  'Sierra Leone' 'Solomon Islands' 'Zambia' 'Guernsey' 'Dominica' 'Cyprus'
#  'Mauritius' 'Israel' 'Nepal' 'Guinea-Bissau' 'Burkina Faso' 'Nigeria'
#  'Paraguay' 'Afghanistan' 'Cayman Islands' 'Canada' 'Micronesia'
#  'Madagascar' 'Botswana' 'Bermuda' 'Tajikistan' 'Korea' 'United Kingdom'
#  'Kiribati' 'Hungary' 'Kenya' 'Suriname' 'Equatorial Guinea' 'Moldova'
#  'Norway' 'Brunei Darussalam' 'Kuwait' 'French Guiana' 'Portugal'
#  'Uzbekistan' 'Liberia' 'Antigua and Barbuda' 'Ecuador' 'Bolivia'
#  'Australia' 'Northern Mariana Islands' 'Reunion' 'Georgia'
#  'New Caledonia' "Lao People's Democratic Republic" 'Swaziland' 'India'
#  'Namibia' 'Maldives' 'Luxembourg' 'Philippines' 'Iran'
#  'Netherlands Antilles' 'Azerbaijan' 'El Salvador' 'Vanuatu' 'Algeria'
#  'Belgium' 'Sweden' 'Central African Republic' 'Tanzania' 'Senegal'
#  'Angola' 'Belize' 'Falkland Islands (Malvinas)' 'Mongolia' 'Morocco'
#  'Nauru' 'New Zealand' 'Venezuela' 'Trinidad and Tobago' 'Argentina'
#  'Serbia' 'Saint Lucia' 'Heard Island and McDonald Islands'
#  "Cote d'Ivoire" 'Guinea' 'Singapore' 'North Macedonia' 'Taiwan'
#  'Saint Barthelemy' 'Jersey' 'Chad' 'Czech Republic' 'Belarus' 'Austria'
#  'Jordan' 'Liechtenstein' 'Somalia' 'Cameroon' 'Grenada'
#  'United States Virgin Islands' 'Tunisia' 'Croatia' 'Switzerland' 'Brazil'
#  'Isle of Man' 'United States Minor Outlying Islands' 'Romania' 'Uganda'
#  'Holy See (Vatican City State)' 'Kyrgyz Republic' 'Tonga'
#  'Papua New Guinea' 'Slovenia' 'Saint Pierre and Miquelon'
#  'Norfolk Island' 'Greece' 'Japan' 'Benin' 'Libyan Arab Jamahiriya'
#  'Sudan' 'Gambia' 'Lebanon' 'Antarctica (the territory South of 60 deg S)'
#  'Burundi' 'Zimbabwe' 'Thailand' 'American Samoa' 'Dominican Republic'
#  'Guadeloupe' 'Togo' 'Guam' 'Christmas Island' 'Gabon' 'Cape Verde'
#  'Sri Lanka' 'Poland' 'Martinique' 'San Marino' 'Hong Kong'
#  'Marshall Islands' 'United Arab Emirates' 'Estonia' 'Haiti'
#  'French Polynesia' 'Malawi' 'Saint Helena' 'Seychelles' 'Macao'
#  'Puerto Rico' 'Eritrea' 'Montenegro' 'Saudi Arabia'
#  'French Southern Territories' 'Qatar' 'Rwanda' 'Gibraltar' 'Turkmenistan'
#  'Palau' 'Uruguay' 'Djibouti' 'Yemen' 'Latvia' 'South Africa' 'Cambodia'
#  'Greenland' 'Niger' 'United States of America' 'Panama' 'Faroe Islands']
# --------------------------------------------------
#
# Analysis for Product:
#
# Counts:
#  Product
# onto          14
# upon          13
# paper         12
# her           12
# music         12
#               ..
# animal         1
# meeting        1
# stop           1
# especially     1
# since          1
# Name: count, Length: 968, dtype: int64
# Proportions:
#  Product
# onto          0.002799
# upon          0.002599
# paper         0.002400
# her           0.002400
# music         0.002400
#                 ...
# animal        0.000200
# meeting       0.000200
# stop          0.000200
# especially    0.000200
# since         0.000200
# Name: proportion, Length: 968, dtype: float64
# Mode: onto
# Unique Values: ['subject' 'course' 'level' 'radio' 'against' 'fine' 'best' 'full' 'both'
#  'never' 'government' 'together' 'idea' 'face' 'who' 'this' 'it' 'live'
#  'discover' 'he' 'young' 'amount' 'personal' 'response' 'police' 'cover'
#  'book' 'hope' 'many' 'care' 'article' 'say' 'whose' 'fact'
#  'environmental' 'buy' 'tax' 'adult' 'sure' 'tough' 'general' 'family'
#  'all' 'change' 'picture' 'know' 'indicate' 'race' 'physical' 'perhaps'
#  'result' 'politics' 'Republican' 'team' 'history' 'similar' 'reach'
#  'teacher' 'everyone' 'mean' 'degree' 'pretty' 'scene' 'research'
#  'mention' 'audience' 'here' 'evidence' 'site' 'marriage' 'form' 'fight'
#  'floor' 'TV' 'interview' 'partner' 'take' 'bring' 'born' 'seek' 'leg'
#  'perform' 'a' 'huge' 'you' 'surface' 'create' 'possible' 'speak' 'study'
#  'not' 'often' 'wife' 'couple' 'mother' 'avoid' 'bill' 'throughout' 'cup'
#  'that' 'specific' 'discuss' 'everything' 'modern' 'authority' 'professor'
#  'computer' 'special' 'view' 'do' 'let' 'most' 'author' 'during' 'stage'
#  'use' 'drop' 'nature' 'money' 'room' 'increase' 'worker' 'window'
#  'environment' 'story' 'be' 'behind' 'agree' 'public' 'wide' 'line'
#  'between' 'onto' 'lawyer' 'help' 'seven' 'play' 'near' 'rise' 'should'
#  'movie' 'learn' 'open' 'reason' 'yourself' 'bank' 'series' 'what'
#  'technology' 'film' 'above' 'participant' 'follow' 'action' 'nation'
#  'job' 'phone' 'television' 'big' 'find' 'seat' 'music' 'part' 'very'
#  'yet' 'realize' 'event' 'teach' 'dream' 'bag' 'walk' 'remain' 'necessary'
#  'population' 'board' 'matter' 'clear' 'attorney' 'compare' 'land' 'baby'
#  'themselves' 'call' 'majority' 'fund' 'thousand' 'once' 'direction'
#  'keep' 'factor' 'safe' 'southern' 'foot' 'chair' 'actually' 'identify'
#  'force' 'town' 'small' 'thought' 'crime' 'her' 'understand' 'sometimes'
#  'bar' 'cell' 'eye' 'financial' 'risk' 'present' 'right' 'central'
#  'economy' 'consumer' 'coach' 'or' 'step' 'recently' 'word' 'rich' 'east'
#  'church' 'heart' 'investment' 'center' 'day' 'himself' 'focus' 'edge'
#  'for' 'apply' 'hold' 'activity' 'believe' 'approach' 'paper' 'produce'
#  'federal' 'ground' 'until' 'will' 'thing' 'fall' 'mission' 'argue'
#  'stand' 'bit' 'move' 'blood' 'the' 'campaign' 'guess' 'wish' 'figure'
#  'situation' 'camera' 'within' 'low' 'some' 'visit' 'interest' 'protect'
#  'your' 'prevent' 'forget' 'various' 'try' 'middle' 'hospital' 'over'
#  'staff' 'smile' 'page' 'cause' 'several' 'feel' 'strong' 'role' 'two'
#  'bad' 'case' 'member' 'business' 'relate' 'pick' 'father' 'individual'
#  'impact' 'hand' 'material' 'hard' 'million' 'experience' 'much' 'away'
#  'child' 'religious' 'address' 'memory' 'six' 'position' 'analysis'
#  'maybe' 'speech' 'meet' 'trouble' 'anything' 'get' 'office' 'gun' 'group'
#  'side' 'Congress' 'available' 'head' 'fast' 'when' 'sit' 'break'
#  'significant' 'leader' 'high' 'each' 'brother' 'enough' 'Mr' 'officer'
#  'war' 'employee' 'four' 'suddenly' 'body' 'including' 'throw' 'lose'
#  'institution' 'foreign' 'organization' 'market' 'she' 'light' 'attention'
#  'daughter' 'later' 'upon' 'establish' 'point' 'deal' 'box' 'make'
#  'agreement' 'add' 'sort' 'have' 'air' 'either' 'truth' 'of' 'price'
#  'rule' 'finish' 'free' 'sign' 'hit' 'test' 'guy' 'official' 'decade'
#  'card' 'into' 'fire' 'production' 'billion' 'north' 'ask' 'carry' 'pass'
#  'court' 'run' 'white' 'as' 'by' 'mouth' 'look' 'system' 'save' 'parent'
#  'affect' 'herself' 'ready' 'car' 'positive' 'catch' 'effect' 'attack'
#  'responsibility' 'human' 'rock' 'candidate' 'age' 'their' 'final' 'great'
#  'without' 'draw' 'director' 'society' 'itself' 'reflect' 'difficult'
#  'next' 'fear' 'another' 'new' 'product' 'whether' 'arrive' 'person'
#  'military' 'then' 'off' 'senior' 'serious' 'industry' 'however' 'plant'
#  'main' 'treatment' 'hotel' 'order' 'medical' 'somebody' 'early'
#  'successful' 'from' 'although' 'trade' 'American' 'after' 'nice'
#  'maintain' 'imagine' 'world' 'region' 'democratic' 'area' 'last' 'sister'
#  'plan' 'little' 'simple' 'simply' 'others' 'our' 'ahead' 'with' 'star'
#  'clearly' 'soon' 'kind' 'concern' 'pull' 'particular' 'out' 'only'
#  'offer' 'me' 'city' 'sense' 'kid' 'exist' 'enter' 'especially' 'enjoy'
#  'leave' 'provide' 'goal' 'could' 'method' 'long' 'if' 'on' 'pattern'
#  'year' 'three' 'entire' 'win' 'people' 'through' 'nothing' 'just'
#  'forward' 'already' 'hour' 'issue' 'choose' 'food' 'stop' 'report'
#  'receive' 'international' 'they' 'thus' 'its' 'dog' 'property' 'citizen'
#  'whatever' 'popular' 'science' 'continue' 'structure' 'cost' 'accept'
#  'require' 'cultural' 'administration' 'discussion' 'cold' 'character'
#  'least' 'item' 'news' 'practice' 'stock' 'term' 'media' 'also' 'state'
#  'week' 'hot' 'conference' 'girl' 'occur' 'under' 'range' 'none' 'eight'
#  'include' 'share' 'according' 'put' 'natural' 'less' 'company'
#  'education' 'cut' 'service' 'recent' 'suffer' 'sell' 'different' 'thank'
#  'nearly' 'gas' 'while' 'relationship' 'lay' 'need' 'travel' 'way'
#  'beyond' 'party' 'better' 'whole' 'back' 'at' 'example' 'list' 'no'
#  'down' 'how' 'allow' 'sing' 'notice' 'eat' 'represent' 'determine' 'give'
#  'manage' 'man' 'manager' 'option' 'defense' 'ever' 'respond' 'wonder'
#  'feeling' 'hear' 'social' 'alone' 'door' 'rate' 'like' 'see' 'set' 'lot'
#  'training' 'hundred' 'act' 'up' 'short' 'number' 'western' 'spring'
#  'friend' 'ball' 'miss' 'language' 'road' 'own' 'quickly' 'per' 'old'
#  'security' 'south' 'benefit' 'water' 'particularly' 'think' 'loss'
#  'resource' 'name' 'player' 'civil' 'fish' 'political' 'red' 'other'
#  'game' 'west' 'these' 'treat' 'more' 'read' 'expert' 'prepare' 'happen'
#  'likely' 'strategy' 'drug' 'rest' 'return' 'begin' 'first' 'really'
#  'college' 'magazine' 'son' 'season' 'prove' 'indeed' 'process' 'there'
#  'single' 'owner' 'can' 'lead' 'yes' 'decide' 'second' 'certainly' 'sport'
#  'moment' 'detail' 'pay' 'country' 'left' 'explain' 'Democrat' 'operation'
#  'important' 'major' 'expect' 'image' 'in' 'ability' 'contain' 'happy'
#  'century' 'good' 'woman' 'national' 'charge' 'student' 'outside' 'appear'
#  'sea' 'summer' 'quite' 'effort' 'boy' 'law' 'trial' 'instead' 'far'
#  'scientist' 'wrong' 'traditional' 'question' 'usually' 'tonight'
#  'exactly' 'shoulder' 'peace' 'whom' 'claim' 'knowledge' 'purpose' 'those'
#  'than' 'few' 'third' 'record' 'tree' 'model' 'bed' 'write' 'agent' 'same'
#  'wind' 'behavior' 'career' 'score' 'because' 'why' 'someone' 'capital'
#  'now' 'about' 'network' 'station' 'tell' 'local' 'hair' 'meeting'
#  'anyone' 'become' 'so' 'past' 'program' 'firm' 'fill' 'beat' 'section'
#  'life' 'go' 'total' 'collection' 'may' 'night' 'almost' 'one' 'stuff'
#  'wall' 'challenge' 'animal' 'them' 'art' 'shake' 'reality' 'piece' 'real'
#  'dark' 'despite' 'but' 'writer' 'minute' 'recognize' 'worry' 'probably'
#  'growth' 'laugh' 'us' 'stay' 'school' 'artist' 'describe' 'success'
#  'before' 'skin' 'late' 'interesting' 'want' 'president' 'improve' 'start'
#  'vote' 'show' 'election' 'unit' 'yeah' 'across' 'letter' 'any' 'send'
#  'heavy' 'performance' 'color' 'glass' 'doctor' 'around' 'again' 'space'
#  'my' 'along' 'tend' 'budget' 'seem' 'large' 'remember' 'base' 'too'
#  'time' 'toward' 'top' 'opportunity' 'such' 'development' 'decision'
#  'value' 'weight' 'theory' 'raise' 'project' 'we' 'assume' 'rather' 'song'
#  'agency' 'mind' 'information' 'quality' 'PM' 'street' 'finally' 'type'
#  'must' 'policy' 'everybody' 'size' 'consider' 'machine' 'green' 'poor'
#  'something' 'chance' 'certain' 'wear' 'answer' 'month' 'Mrs' 'debate'
#  'current' 'drive' 'measure' 'statement' 'him' 'even' 'might' 'ago' 'end'
#  'fly' 'morning' 'difference' 'talk' 'today' 'culture' 'close' 'build'
#  'choice' 'and' 'data' 'blue' 'inside' 'executive' 'admit' 'nor' 'suggest'
#  'place' 'yard' 'myself' 'work' 'well' 'home' 'black' 'garden' 'his'
#  'still' 'skill' 'husband' 'ok' 'oil' 'though' 'condition' 'would'
#  'economic' 'beautiful' 'evening' 'easy' 'turn' 'former' 'serve' 'kitchen'
#  'push' 'health' 'TRUE' 'standard' 'reduce' 'commercial' 'management'
#  'note' 'able' 'power' 'develop' 'where' 'design' 'source' 'support'
#  'check' 'arm' 'sound' 'key' 'customer' 'style' 'watch' 'community'
#  'front' 'generation' 'to' 'store' 'professional' 'listen' 'energy'
#  'field' 'pressure' 'class' 'message' 'common' 'painting' 'I' 'half'
#  'join' 'wait' 'reveal' 'among' 'task' 'else' 'control' 'grow' 'which'
#  'house' 'dinner' 'future' 'five' 'table' 'spend' 'movement' 'threat'
#  'always' 'ten' 'account' 'trip' 'building' 'involve' 'soldier' 'every'
#  'since']
# --------------------------------------------------
#
# Analysis for Import_Export:
#
# Counts:
#  Import_Export
# Import    2541
# Export    2460
# Name: count, dtype: int64
# Proportions:
#  Import_Export
# Import    0.508098
# Export    0.491902
# Name: proportion, dtype: float64
# Mode: Import
# Unique Values: ['Export' 'Import']
# --------------------------------------------------
#
# Analysis for Category:
#
# Counts:
#  Category
# Electronics    1021
# Clothing       1011
# Furniture      1010
# Machinery       987
# Toys            972
# Name: count, dtype: int64
# Proportions:
#  Category
# Electronics    0.204159
# Clothing       0.202160
# Furniture      0.201960
# Machinery      0.197361
# Toys           0.194361
# Name: proportion, dtype: float64
# Mode: Electronics
# Unique Values: ['Electronics' 'Furniture' 'Clothing' 'Toys' 'Machinery']
# --------------------------------------------------
#
# Analysis for Port:
#
# Counts:
#  Port
# South Robert        8
# Port David          7
# South Michael       7
# South James         6
# Johnstad            6
#                    ..
# South Tylerburgh    1
# Connerport          1
# Lake Barbara        1
# New Gabrielshire    1
# North Lisabury      1
# Name: count, Length: 4247, dtype: int64
# Proportions:
#  Port
# South Robert        0.0016
# Port David          0.0014
# South Michael       0.0014
# South James         0.0012
# Johnstad            0.0012
#                      ...
# South Tylerburgh    0.0002
# Connerport          0.0002
# Lake Barbara        0.0002
# New Gabrielshire    0.0002
# North Lisabury      0.0002
# Name: proportion, Length: 4247, dtype: float64
# Mode: South Robert
# Unique Values: ['Lake Sabrinafort' 'South Ryan' 'Henryview' ... 'East Katherine'
#  'Lake Ricardoborough' 'North Lisabury']
# --------------------------------------------------
#
# Analysis for Customs_Code:
#
# Counts:
#  Customs_Code
# 533882    2
# 726955    2
# 557982    2
# 411136    2
# 959969    2
#          ..
# 888214    1
# 871790    1
# 788068    1
# 497109    1
# 161318    1
# Name: count, Length: 4989, dtype: int64
# Proportions:
#  Customs_Code
# 533882    0.0004
# 726955    0.0004
# 557982    0.0004
# 411136    0.0004
# 959969    0.0004
#            ...
# 888214    0.0002
# 871790    0.0002
# 788068    0.0002
# 497109    0.0002
# 161318    0.0002
# Name: proportion, Length: 4989, dtype: float64
# Mode: 100171
# Unique Values: [699459 373935 568552 ... 239621 529262 161318]
# --------------------------------------------------
#
# Analysis for Shipping_Method:
#
# Counts:
#  Shipping_Method
# Air     1671
# Land    1665
# Sea     1665
# Name: count, dtype: int64
# Proportions:
#  Shipping_Method
# Air     0.334133
# Land    0.332933
# Sea     0.332933
# Name: proportion, dtype: float64
# Mode: Air
# Unique Values: ['Land' 'Sea' 'Air']
# --------------------------------------------------
#
# Analysis for Supplier:
#
# Counts:
#  Supplier
# Johnson Inc                 8
# Johnson PLC                 8
# Williams LLC                7
# Smith Ltd                   7
# Anderson PLC                6
#                            ..
# Bass, Mejia and Thompson    1
# Lopez-Hernandez             1
# Jones-Brandt                1
# Adams Group                 1
# Suarez-Davis                1
# Name: count, Length: 4565, dtype: int64
# Proportions:
#  Supplier
# Johnson Inc                 0.0016
# Johnson PLC                 0.0016
# Williams LLC                0.0014
# Smith Ltd                   0.0014
# Anderson PLC                0.0012
#                              ...
# Bass, Mejia and Thompson    0.0002
# Lopez-Hernandez             0.0002
# Jones-Brandt                0.0002
# Adams Group                 0.0002
# Suarez-Davis                0.0002
# Name: proportion, Length: 4565, dtype: float64
# Mode: Johnson Inc
# Unique Values: ['Hart Group' 'Rogers, Mccarty and Griffith'
#  'Vasquez, Little and Villanueva' ... 'Cruz, Black and Robinson'
#  'Douglas, Armstrong and Hamilton' 'Suarez-Davis']
# --------------------------------------------------
#
# Analysis for Customer:
#
# Counts:
#  Customer
# Michael Brown        6
# Robert Brown         4
# Cheryl Harris        3
# Jennifer Williams    3
# Michael Miller       3
#                     ..
# Vickie Gibson        1
# Jeffrey Waters       1
# Rodney Foster        1
# Aaron Gross          1
# Benjamin Duke        1
# Name: count, Length: 4845, dtype: int64
# Proportions:
#  Customer
# Michael Brown        0.0012
# Robert Brown         0.0008
# Cheryl Harris        0.0006
# Jennifer Williams    0.0006
# Michael Miller       0.0006
#                       ...
# Vickie Gibson        0.0002
# Jeffrey Waters       0.0002
# Rodney Foster        0.0002
# Aaron Gross          0.0002
# Benjamin Duke        0.0002
# Name: proportion, Length: 4845, dtype: float64
# Mode: Michael Brown
# Unique Values: ['Joann Campos' 'Brian Black' 'Melissa Henry' ... 'Emma Lopez'
#  'Sarah Porter' 'Benjamin Duke']
# --------------------------------------------------
#
# Analysis for Invoice_Number:
#
# Counts:
#  Invoice_Number
# 81130044    1
# 53703096    1
# 85407787    1
# 9607433     1
# 95491615    1
#            ..
# 31409492    1
# 19081436    1
# 11073895    1
# 25693969    1
# 69435222    1
# Name: count, Length: 5001, dtype: int64
# Proportions:
#  Invoice_Number
# 81130044    0.0002
# 53703096    0.0002
# 85407787    0.0002
# 9607433     0.0002
# 95491615    0.0002
#              ...
# 31409492    0.0002
# 19081436    0.0002
# 11073895    0.0002
# 25693969    0.0002
# 69435222    0.0002
# Name: proportion, Length: 5001, dtype: float64
# Mode: 42026
# Unique Values: [81130044 18100184 30029769 ... 69250034 47771810 69435222]
# --------------------------------------------------
#
# Analysis for Payment_Terms:
#
# Counts:
#  Payment_Terms
# Cash on Delivery    1302
# Net 60              1270
# Prepaid             1238
# Net 30              1191
# Name: count, dtype: int64
# Proportions:
#  Payment_Terms
# Cash on Delivery    0.260348
# Net 60              0.253949
# Prepaid             0.247550
# Net 30              0.238152
# Name: proportion, dtype: float64
# Mode: Cash on Delivery
# Unique Values: ['Net 30' 'Cash on Delivery' 'Net 60' 'Prepaid']
# --------------------------------------------------

# %%
import scipy.stats as stats
import numpy as np

# Assuming df_sampled is your DataFrame and 'Value' and 'Weight' are your numeric columns

# 1. Test of Mean
# t-test for two independent samples
t_stat, t_p_value = stats.ttest_ind(AA02_sample_data_0['Value'], AA02_sample_data_0['Weight'], equal_var=False)
print("t-test:", t_stat, t_p_value)

# ANOVA for more than two groups (Example with a categorical variable 'Category')


data_groups = [AA02_sample_data_0['Value'][AA02_sample_data_0['Category'] == category] for category in AA02_sample_data_0['Category'].unique()]
anova_result = stats.f_oneway(*data_groups)
print("ANOVA:", anova_result)

# 2. Test of Variance
# Levene's Test
levene_stat, levene_p = stats.levene(AA02_sample_data_0['Value'], AA02_sample_data_0['Weight'])
print("Levene's test:", levene_stat, levene_p)

# 3. Test of Proportion (Using a categorical example, e.g., Import_Export)
import statsmodels.api as sm
# Prepare data
(success, total) = sm.stats.proportion_confint(count=AA02_sample_data_0['Import_Export'].value_counts()['Import'],
                                                nobs=AA02_sample_data_0['Import_Export'].count(),
                                                alpha=0.05)
print("Proportion test:", success, total)

# 4. Test of Correlation
# Pearson correlation
corr_coeff, corr_p = stats.pearsonr(AA02_sample_data_0['Value'], AA02_sample_data_0['Weight'])
print("Correlation test:", corr_coeff, corr_p)

# 5. Test of Normality
# Shapiro-Wilk Test
shapiro_test = stats.shapiro(AA02_sample_data_0['Value'])
print("Shapiro-Wilk test:", shapiro_test)

# 6. Non-Parametric Tests
# Mann-Whitney U Test
u_stat, u_p = stats.mannwhitneyu(AA02_sample_data_0['Value'], AA02_sample_data_0['Weight'], alternative='two-sided')
print("Mann-Whitney U test:", u_stat, u_p)
# Out:
# t-test: 54.816030266629774 0.0
# ANOVA: F_onewayResult(statistic=1.44131973241727, pvalue=0.21755176939234142)
# Levene's test: 2761.85682794127 0.0
# Proportion test: 0.4942425455696623 0.521954215078208
# Correlation test: 0.030647535103422902 0.03021259829220137
# Shapiro-Wilk test: ShapiroResult(statistic=0.9566079723369941, pvalue=3.3478428118235835e-36)
# Mann-Whitney U test: 18811661.5 0.0
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 5001.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
import pandas as pd
import scipy.stats as stats

# Create a contingency table for two categorical variables
contingency_table = pd.crosstab(AA02_sample_data_0['Category'], AA02_sample_data_0['Shipping_Method'])

# Perform the Chi-squared test of independence
chi2_stat, p_val, dof, expected = stats.chi2_contingency(contingency_table)

print("Chi-squared Test Result:")
print(f"Chi-squared Statistic: {chi2_stat}")
print(f"p-value: {p_val}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies Table:")
print(expected)
# Out:
# Chi-squared Test Result:
# Chi-squared Statistic: 3.8324405106638766
# p-value: 0.871915882471516
# Degrees of Freedom: 8
# Expected Frequencies Table:
# [[337.80863827 336.59568086 336.59568086]
#  [341.14997001 339.925015   339.925015  ]
#  [337.4745051  336.26274745 336.26274745]
#  [329.78944211 328.60527894 328.60527894]
#  [324.77744451 323.61127774 323.61127774]]

# %%
# Mann-Whitney U Test between two independent groups (e.g., Shipping_Method 'Air' vs 'Sea')
group1 = AA02_sample_data_0['Value'][AA02_sample_data_0['Shipping_Method'] == 'Air']
group2 = AA02_sample_data_0['Value'][AA02_sample_data_0['Shipping_Method'] == 'Sea']

u_stat, u_p_value = stats.mannwhitneyu(group1, group2)
print("Mann-Whitney U Test Result:")
print(f"U Statistic: {u_stat}, p-value: {u_p_value}")
# Out:
# Mann-Whitney U Test Result:
# U Statistic: 1342785.0, p-value: 0.08234322455878211

# %%
# Kruskal-Wallis H Test for multiple groups in 'Category'
kw_stat, kw_p_value = stats.kruskal(AA02_sample_data_0['Value'][AA02_sample_data_0['Category'] == 'Electronics'],
                                    AA02_sample_data_0['Value'][AA02_sample_data_0['Category'] == 'Furniture'],
                                    AA02_sample_data_0['Value'][AA02_sample_data_0['Category'] == 'Clothing'])
print("Kruskal-Wallis H Test Result:")
print(f"Kruskal-Wallis Statistic: {kw_stat}, p-value: {kw_p_value}")
# Out:
# Kruskal-Wallis H Test Result:
# Kruskal-Wallis Statistic: 3.488687469833494, p-value: 0.17475963999165223

# %%
import scipy.stats as stats

# Kruskal-Wallis test to compare Value across different Categories
kw_stat, kw_p_value = stats.kruskal(AA02_sample_data_0['Value'][AA02_sample_data_0['Category'] == 'Electronics'],
                                    AA02_sample_data_0['Value'][AA02_sample_data_0['Category'] == 'Furniture'],
                                    AA02_sample_data_0['Value'][AA02_sample_data_0['Category'] == 'Clothing'],
                                    AA02_sample_data_0['Value'][AA02_sample_data_0['Category'] == 'Toys'],
                                    AA02_sample_data_0['Value'][AA02_sample_data_0['Category'] == 'Machinery'])

print("Kruskal-Wallis Test Result:")
print(f"Kruskal-Wallis Statistic: {kw_stat}, p-value: {kw_p_value}")
# Out:
# Kruskal-Wallis Test Result:
# Kruskal-Wallis Statistic: 5.737022759619848, p-value: 0.21966720045740298

# %%
import statsmodels.api as sm

# Define the independent variables (Quantity, Weight)
X = AA02_sample_data_0[['Quantity', 'Weight']]

# Add a constant (intercept term) to the model
X = sm.add_constant(X)

# Define the dependent variable (Value)
y = AA02_sample_data_0['Value']

# Fit the regression model
model = sm.OLS(y, X).fit()

# Print the summary of the model
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Value   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.353
# Date:                Mon, 06 Jan 2025   Prob (F-statistic):             0.0952
# Time:                        00:12:18   Log-Likelihood:                -46875.
# No. Observations:                5001   AIC:                         9.376e+04
# Df Residuals:                    4998   BIC:                         9.378e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4823.3742    105.648     45.655      0.000    4616.257    5030.491
# Quantity       0.0011      0.014      0.079      0.937      -0.026       0.028
# Weight         0.0600      0.028      2.168      0.030       0.006       0.114
# ==============================================================================
# Omnibus:                     3499.756   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              289.103
# Skew:                           0.023   Prob(JB):                     1.67e-63
# Kurtosis:                       1.823   Cond. No.                     1.63e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.63e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import numpy as np

# Define the independent variable (e.g., Quantity)
X = AA02_sample_data_0[['Quantity']]

# Transform the independent variable to include polynomial terms (degree 2)
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# Define the dependent variable (Value)
y = AA02_sample_data_0['Value']

# Fit the polynomial regression model
model = LinearRegression()
model.fit(X_poly, y)

# Print the coefficients
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)

# Predict values based on the polynomial model
y_pred = model.predict(X_poly)

# Model evaluation
from sklearn.metrics import r2_score
r2 = r2_score(y, y_pred)
print(f'R-squared: {r2}')
# Out:
# Coefficients: [ 0.00000000e+00  4.03683100e-02 -3.92386216e-06]
# Intercept: 4908.216316776716
# R-squared: 0.00010920389614987869

# %%
import pandas as pd
import statsmodels.api as sm
from sklearn.preprocessing import LabelEncoder

# Encode the categorical dependent variable 'Import_Export' (0 for Import, 1 for Export)
AA02_sample_data_0['Import_Export_Encoded'] = LabelEncoder().fit_transform(AA02_sample_data_0['Import_Export'])

# Define the independent variables (you can include both categorical and continuous variables)
X = AA02_sample_data_0[['Quantity', 'Weight']]  # Add more predictors if needed

# Add a constant (intercept term) to the model
X = sm.add_constant(X)

# Define the dependent variable (Import_Export)
y = AA02_sample_data_0['Import_Export_Encoded']

# Fit the logistic regression model
logit_model = sm.Logit(y, X).fit()

# Print the summary of the model
print(logit_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.692996
#          Iterations 3
#                              Logit Regression Results
# =================================================================================
# Dep. Variable:     Import_Export_Encoded   No. Observations:                 5001
# Model:                             Logit   Df Residuals:                     4998
# Method:                              MLE   Df Model:                            2
# Date:                   Mon, 06 Jan 2025   Pseudo R-squ.:               2.863e-05
# Time:                           00:13:22   Log-Likelihood:                -3465.7
# converged:                          True   LL-Null:                       -3465.8
# Covariance Type:               nonrobust   LLR p-value:                    0.9055
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0629      0.074      0.848      0.397      -0.083       0.208
# Quantity   -2.853e-06   9.72e-06     -0.293      0.769   -2.19e-05    1.62e-05
# Weight     -6.511e-06   1.94e-05     -0.335      0.738   -4.46e-05    3.16e-05
# ==============================================================================

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Categorizing Variables

# %%
AA02_sample_data_0.columns
# Out:
# Index(['Transaction_ID', 'Country', 'Product', 'Import_Export', 'Quantity',
#        'Value', 'Date', 'Category', 'Port', 'Customs_Code', 'Weight',
#        'Shipping_Method', 'Supplier', 'Customer', 'Invoice_Number',
#        'Payment_Terms'],
#       dtype='object')

# %%
# Check whether a Variable is index or not
AA02_check_unique_values(AA02_sample_data_0)
# Out:
#                  Unique Values  Total Values  Percentage (%)
# Transaction_ID            5001          5001      100.000000
# Country                    243          5001        4.859028
# Product                    968          5001       19.356129
# Import_Export                2          5001        0.039992
# Quantity                  3924          5001       78.464307
# Value                     4985          5001       99.680064
# Date                      1700          5001       33.993201
# Category                     5          5001        0.099980
# Port                      4247          5001       84.923015
# Customs_Code              4989          5001       99.760048
# Weight                    4976          5001       99.500100
# Shipping_Method              3          5001        0.059988
# Supplier                  4565          5001       91.281744
# Customer                  4845          5001       96.880624
# Invoice_Number            5001          5001      100.000000
# Payment_Terms                4          5001        0.079984

# %%
AA02_columns= ['Country', 'Product', 'Import_Export', 'Quantity', 'Value', 'Category', 'Port', 'Weight', 'Shipping_Method', 'Payment_Terms']

# %%
AA02_sample_data_1 = AA02_sample_data_0[AA02_columns]
AA02_sample_data_1.head(3)
# Out:
#                   Country  Product Import_Export  Quantity    Value  \
# 10200               Malta  subject        Export      1502  1839.60
# 5670             Ethiopia   course        Export      8996  7345.69
# 4482   Russian Federation   course        Export      5388  3963.55
#
#           Category              Port   Weight Shipping_Method  \
# 10200  Electronics  Lake Sabrinafort  1389.59            Land
# 5670     Furniture        South Ryan  4261.19             Sea
# 4482      Clothing         Henryview  3076.02             Sea
#
#           Payment_Terms
# 10200            Net 30
# 5670   Cash on Delivery
# 4482   Cash on Delivery

# %%
# Verify whether all variables are non index variables
AA02_check_unique_values(AA02_sample_data_1)
# Out:
#                  Unique Values  Total Values  Percentage (%)
# Country                    243          5001        4.859028
# Product                    968          5001       19.356129
# Import_Export                2          5001        0.039992
# Quantity                  3924          5001       78.464307
# Value                     4985          5001       99.680064
# Category                     5          5001        0.099980
# Port                      4247          5001       84.923015
# Weight                    4976          5001       99.500100
# Shipping_Method              3          5001        0.059988
# Payment_Terms                4          5001        0.079984

# %%
AA02_categorical_columns = ['Country', 'Product', 'Import_Export', 'Category', 'Port', 'Shipping_Method', 'Payment_Terms']
AA02_non_categorical_columns = ['Quantity', 'Value', 'Weight']

# %%
AA02_categorical_ordinal_columns = []
AA02_categorical_nominal_columns = ['Country', 'Product', 'Category', 'Port', 'Shipping_Method', 'Payment_Terms', 'Import_Export']

# %% [markdown]
# ## Imputation

# %% [markdown]
# ### Checking Missing Percentage

# %%
import pandas as pd

# Function to calculate missing data information
def AA02_missing_data_info(AA02_sample_data):
    # Calculate missing count and percentage
    AA02_missing_count = AA02_sample_data.isnull().sum()
    AA02_missing_percentage = (AA02_missing_count / len(AA02_sample_data)) * 100

    # Create a DataFrame with missing data information
    AA02_missing_info = pd.DataFrame({
        'AA02_Variable': AA02_sample_data.columns,
        'AA02_Missing_Count': AA02_missing_count.values,
        'AA02_Missing_Percentage': AA02_missing_percentage.values
    }).reset_index(drop=True)

    # Format the percentage column
    AA02_missing_info['AA02_Missing_Percentage'] = AA02_missing_info['AA02_Missing_Percentage'].round(2).astype(str) + '%'

    return AA02_missing_info

# Call the function
AA02_missing_data_info(AA02_sample_data_1)
# Out:
#      AA02_Variable  AA02_Missing_Count AA02_Missing_Percentage
# 0          Country                   0                    0.0%
# 1          Product                   0                    0.0%
# 2    Import_Export                   0                    0.0%
# 3         Quantity                   0                    0.0%
# 4            Value                   0                    0.0%
# 5         Category                   0                    0.0%
# 6             Port                   0                    0.0%
# 7           Weight                   0                    0.0%
# 8  Shipping_Method                   0                    0.0%
# 9    Payment_Terms                   0                    0.0%

# %% [markdown]
# ### Drop Variable

# %%
import pandas as pd

# Function to omit variables with more than a threshold of missing values and log omitted variables
def AA02_clean_data_with_logging(
    AA02_sample_data,
    AA02_categorical_columns,
    AA02_non_categorical_columns,
    AA02_columns,
    missing_threshold=50
):
    # Calculate missing percentage for each variable
    AA02_missing_percentage = (AA02_sample_data.isnull().sum() / len(AA02_sample_data)) * 100

    # Identify variables to omit (missing percentage > threshold)
    variables_to_omit = AA02_missing_percentage[AA02_missing_percentage > missing_threshold]

    # Create a DataFrame for omitted variables
    omitted_info = []
    for variable, percentage in variables_to_omit.items():
        if variable in AA02_categorical_columns:
            source = "AA02_categorical_columns"
        elif variable in AA02_non_categorical_columns:
            source = "AA02_non_categorical_columns"
        elif variable in AA02_columns:
            source = "AA02_columns"
        else:
            source = "Unknown"

        omitted_info.append({
            "Variable": variable,
            "Missing_Percentage": round(percentage, 2),
            "Omitted_From": source
        })

    # Convert omitted info to DataFrame
    AA02_omitted_df = pd.DataFrame(omitted_info)

    # Identify variables to keep
    variables_to_keep = AA02_missing_percentage[AA02_missing_percentage <= missing_threshold].index.tolist()

    # Filter the dataset
    AA02_sample_data_cleaned = AA02_sample_data[variables_to_keep]

    # Update the lists (only keep variables that are not omitted)
    AA02_columns[:] = [col for col in AA02_columns if col in variables_to_keep]
    AA02_categorical_columns[:] = [col for col in AA02_categorical_columns if col in variables_to_keep]
    AA02_non_categorical_columns[:] = [col for col in AA02_non_categorical_columns if col in variables_to_keep]

    # Print the DataFrame of omitted variables
    print("Variables Omitted Due to Missing Values (> {}%):".format(missing_threshold))
    print(AA02_omitted_df)

    return AA02_sample_data_cleaned

# Example usage
# Assuming AA02_sample_data_1, AA02_categorical_columns, AA02_non_categorical_columns, and AA02_columns are defined
AA02_sample_data_cleaned = AA02_clean_data_with_logging(
    AA02_sample_data_1,
    AA02_categorical_columns,
    AA02_non_categorical_columns,
    AA02_columns,
    missing_threshold=50
)
# Out:
# Variables Omitted Due to Missing Values (> 50%):
# Empty DataFrame
# Columns: []
# Index: []

# %%
AA02_sample_data_dropped_variable = AA02_sample_data_1[AA02_columns]

# %% [markdown]
# ### Categorical Imputation

# %%
from sklearn.impute import SimpleImputer

AA02_sample_data_imputed = AA02_sample_data_dropped_variable.copy()

# Initialize SimpleImputer with most_frequent strategy
AA02_imputer = SimpleImputer(strategy='most_frequent')

# Apply imputation
AA02_sample_data_imputed[AA02_categorical_columns] = AA02_imputer.fit_transform(AA02_sample_data_imputed[AA02_categorical_columns])

# %% [markdown]
# ### Non Categorical Imputation

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

from sklearn.impute import SimpleImputer
import numpy as np

def AA02_impute_columns_with_mean_or_median(AA02_df, columns):
    for col in columns:
        # Ensure column is numeric
        AA02_df[col] = pd.to_numeric(AA02_df[col], errors='coerce')

        # Replace invalid values with NaN
        AA02_df[col].replace([np.inf, -np.inf], np.nan, inplace=True)

        # Skip if column has no missing values
        if AA02_df[col].isnull().sum() == 0:
            continue

        # Calculate mean and median
        AA02_col_mean = AA02_df[col].mean()
        AA02_col_median = AA02_df[col].median()

        # Choose strategy based on significant difference
        if abs(AA02_col_mean - AA02_col_median) / max(abs(AA02_col_mean), abs(AA02_col_median)) > 0.1:  # Significant difference
            print(f"Imputing '{col}' with median (significant difference between mean and median)")
            AA02_imputer = SimpleImputer(strategy='median')
        else:
            print(f"Imputing '{col}' with mean (no significant difference between mean and median)")
            AA02_imputer = SimpleImputer(strategy='mean')

        # Apply the AA02_imputer
        AA02_df[[col]] = AA02_imputer.fit_transform(AA02_df[[col]])

    return AA02_df

AA02_sample_data_imputed = AA02_impute_columns_with_mean_or_median(AA02_sample_data_imputed, AA02_non_categorical_columns)

# %% [markdown]
# ### Verify Missing Percetage = 0

# %%
AA02_missing_data_info(AA02_sample_data_imputed)
# Out:
#      AA02_Variable  AA02_Missing_Count AA02_Missing_Percentage
# 0          Country                   0                    0.0%
# 1          Product                   0                    0.0%
# 2    Import_Export                   0                    0.0%
# 3         Quantity                   0                    0.0%
# 4            Value                   0                    0.0%
# 5         Category                   0                    0.0%
# 6             Port                   0                    0.0%
# 7           Weight                   0                    0.0%
# 8  Shipping_Method                   0                    0.0%
# 9    Payment_Terms                   0                    0.0%

# %% [markdown]
# ## Numerical Encoding

# %% [markdown]
# ### Ordinal/Nominal Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

# Define order for ordinal columns
AA02_ordinal_categories = [
    # ['Import', 'Export'],  # Order for 'Import_Export'
    # ['B', 'A']             # Order for 'Grades' (A is superior to B) A will be written as 1 and b will be written as 0
]
# Initialize OrdinalEncoder for ordinal columns with specified order
ordinal_encoder_ordinal = OrdinalEncoder(categories=AA02_ordinal_categories)

# Initialize OrdinalEncoder for nominal columns (order does not matter)
ordinal_encoder_nominal = OrdinalEncoder()

# Make a copy of the DataFrame
AA02_sample_data_ordinally_encoded = AA02_sample_data_imputed.copy()

# Encode ordinal columns
AA02_sample_data_ordinally_encoded[AA02_categorical_ordinal_columns] = ordinal_encoder_ordinal.fit_transform(
    AA02_sample_data_ordinally_encoded[AA02_categorical_ordinal_columns].astype(str)
)

# Encode nominal columns
AA02_sample_data_ordinally_encoded[AA02_categorical_nominal_columns] = ordinal_encoder_nominal.fit_transform(
    AA02_sample_data_ordinally_encoded[AA02_categorical_nominal_columns].astype(str)
)

# AA02_display the encoded DataFrame
print("DataFrame with Encoded Categorical Variables:")
AA02_sample_data_ordinally_encoded.head()
# Out:
# DataFrame with Encoded Categorical Variables:
#        Country  Product  Import_Export  Quantity    Value  Category    Port  \
# 10200    132.0    816.0            0.0      1502  1839.60       1.0  1737.0
# 5670      67.0    193.0            0.0      8996  7345.69       2.0  3587.0
# 4482     179.0    193.0            0.0      5388  3963.55       0.0  1123.0
# 4739      15.0    458.0            1.0      1292  3940.89       1.0   556.0
# 1631     185.0    663.0            1.0      4219  5116.03       1.0   701.0
#
#         Weight  Shipping_Method  Payment_Terms
# 10200  1389.59              1.0            1.0
# 5670   4261.19              2.0            0.0
# 4482   3076.02              2.0            0.0
# 4739   4685.04              1.0            2.0
# 1631   4151.79              0.0            2.0

# %% [markdown]
# ## Transformation

# %%
import numpy as np
from scipy.stats import boxcox
from sklearn.preprocessing import PowerTransformer
import pandas as pd

# Function to handle transformations based on distribution characteristics
def apply_transformations(AA02_sample_data, columns):
    # Initialize a list to store transformation logs
    AA02_transformation_logs = []

    for column in columns:
        # Compute AA02_skewness and AA02_kurtosis
        AA02_skewness = AA02_sample_data[column].skew()
        AA02_kurtosis = AA02_sample_data[column].kurt()
        AA02_action = "None"  # Default AA02_action

        # Handle Right Skew (Positive Skew)
        if AA02_skewness > 1:
            AA02_action = "Log Transformation"
            AA02_sample_data[column] = np.log1p(AA02_sample_data[column])

        # Handle Left Skew (Negative Skew)
        elif AA02_skewness < -1:
            AA02_action = "Reflect and Log Transformation"
            AA02_sample_data[column] = np.log1p(AA02_sample_data[column].max() - AA02_sample_data[column])

        # Handle High Kurtosis (Heavy Tails)
        if AA02_kurtosis > 3:
            try:
                AA02_action = "Box-Cox Transformation"
                AA02_sample_data[column], _ = boxcox(AA02_sample_data[column].clip(lower=1))
            except ValueError:
                AA02_action = "Box-Cox Failed, Applied Yeo-Johnson"
                transformer = PowerTransformer(method='yeo-johnson')
                AA02_sample_data[column] = transformer.fit_transform(AA02_sample_data[[column]])

        # Handle Low Kurtosis (Light Tails)
        elif AA02_kurtosis < 3 and AA02_action == "None":
            AA02_action = "Yeo-Johnson Transformation"
            transformer = PowerTransformer(method='yeo-johnson')
            AA02_sample_data[column] = transformer.fit_transform(AA02_sample_data[[column]])

        # Append the log entry
        AA02_transformation_logs.append({
            'Column Name': column,
            'Skewness': AA02_skewness,
            'Kurtosis': AA02_kurtosis,
            'Action Taken': AA02_action
        })

    # Create a DataFrame for transformation logs
    transformation_log_AA02_df = pd.DataFrame(AA02_transformation_logs)
    return AA02_sample_data, transformation_log_AA02_df

# Example usage with AA02_sample_data_encoded
AA02_sample_data_encoded = AA02_sample_data_ordinally_encoded.copy()
AA02_sample_data_encoded, AA02_transformation_logs = apply_transformations(AA02_sample_data_encoded, AA02_non_categorical_columns)

# AA02_display the transformation log DataFrame
print("Transformation Log:")
AA02_transformation_logs
# Out:
# Transformation Log:
#   Column Name  Skewness  Kurtosis                Action Taken
# 0    Quantity  0.012114 -1.206397  Yeo-Johnson Transformation
# 1       Value  0.020697 -1.177549  Yeo-Johnson Transformation
# 2      Weight  0.017801 -1.206430  Yeo-Johnson Transformation

# %%
# Code for AA02_displaying transformed datset
AA02_sample_data_encoded.head(5)
# Out:
#        Country  Product  Import_Export  Quantity     Value  Category    Port  \
# 10200    132.0    816.0            0.0 -1.197225 -1.080379       1.0  1737.0
# 5670      67.0    193.0            0.0  1.275318  0.836078       2.0  3587.0
# 4482     179.0    193.0            0.0  0.232745 -0.249928       0.0  1123.0
# 4739      15.0    458.0            1.0 -1.296379 -0.257956       1.0   556.0
# 1631     185.0    663.0            1.0 -0.147615  0.142650       1.0   701.0
#
#          Weight  Shipping_Method  Payment_Terms
# 10200 -0.670792              1.0            1.0
# 5670   1.144909              2.0            0.0
# 4482   0.463580              2.0            0.0
# 4739   1.374136              1.0            2.0
# 1631   1.084650              0.0            2.0

# %% [markdown]
# # Clustor Analysis

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %% [markdown]
# ## KMeans Clustor Analysis

# %%
AA02_sample_data_clustor = AA02_sample_data_encoded.copy()
from sklearn.metrics import silhouette_score

AA02_silhouette_scores = []
AA02_k_values = range(2, 6)  # Silhouette score requires at least 2 clusters

for AA02_k in AA02_k_values:
    AA02_kmeans = KMeans(n_clusters=AA02_k, random_state=55002, n_init=10)
    AA02_cluster_labels = AA02_kmeans.fit_predict(AA02_sample_data_clustor[AA02_categorical_columns + AA02_non_categorical_columns])
    AA02_silhouette_scores.append(silhouette_score(AA02_sample_data_clustor[AA02_categorical_columns + AA02_non_categorical_columns], AA02_cluster_labels))

# %% [markdown]
# ## Elbow Plot

# %%
# Plot the Silhouette Scores
plt.figure(figsize=(10, 6))
plt.plot(AA02_k_values, AA02_silhouette_scores, marker='o')
plt.title('Silhouette Scores for Determining Optimal Clusters')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.grid()
plt.show()

# %% [markdown]
# # Agglomerative Clustering

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# Step 1: Extract relevant columns for clustering
AA02_clustering_data = AA02_sample_data_clustor[AA02_columns]

# Step 2: Perform hierarchical clustering (Ward's method)
AA02_linkage_matrix = linkage(AA02_clustering_data, method='ward')

# %% [markdown]
# ## Dendrogram Plot

# %%
# Step 3: Plot the dendrogram
plt.figure(figsize=(12, 8))
dendrogram(AA02_linkage_matrix, labels=AA02_clustering_data.index, leaf_rotation=90, leaf_font_size=10)
plt.title('Dendrogram for Hierarchical Clustering')
plt.xlabel('Samples')
plt.ylabel('Euclidean Distance')
plt.grid(True)
plt.show()
